# %%
# 1 .import the necessary libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# 2. Import the dataset from the address given
df = pd.read_csv('wine.data')

# %%
df.head()
# Out:
#    1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29  5.64  1.04  3.92  \
# 0  1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28  4.38  1.05  3.40
# 1  1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81  5.68  1.03  3.17
# 2  1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18  7.80  0.86  3.45
# 3  1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82  4.32  1.04  2.93
# 4  1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97  6.75  1.05  2.85
#
#    1065
# 0  1050
# 1  1185
# 2  1480
# 3   735
# 4  1450

# %%
# 3. Assign it to a varaible called wine
wine = df

# %%
# 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

wine.drop(wine.columns[[0,3,6,8,10,12,13]],axis=1)
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# ..     ...   ...   ...  ...   ...   ...   ...
# 172  13.71  5.65  20.5   95  0.61  1.06  0.64
# 173  13.40  3.91  23.0  102  0.75  1.41  0.70
# 174  13.27  4.28  20.0  120  0.69  1.35  0.59
# 175  13.17  2.59  20.0  120  0.68  1.46  0.60
# 176  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [177 rows x 7 columns]

# %%
# 5. Assign the column names
wine.columns=['Type','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# %%
wine.head()
# Out:
#    Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0     1    13.20        1.78  2.14               11.2        100
# 1     1    13.16        2.36  2.67               18.6        101
# 2     1    14.37        1.95  2.50               16.8        113
# 3     1    13.24        2.59  2.87               21.0        118
# 4     1    14.20        1.76  2.45               15.2        112
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# 1             5.68  1.03                          3.17     1185
# 2             7.80  0.86                          3.45     1480
# 3             4.32  1.04                          2.93      735
# 4             6.75  1.05                          2.85     1450

# %%
# 6. Set the values of the first 3 rows from alcohol as NaN
wine['Alcohol'][0:3] = np.nan
wine.head()
# Out:
#    Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0     1      NaN        1.78  2.14               11.2        100
# 1     1      NaN        2.36  2.67               18.6        101
# 2     1      NaN        1.95  2.50               16.8        113
# 3     1    13.24        2.59  2.87               21.0        118
# 4     1    14.20        1.76  2.45               15.2        112
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# 1             5.68  1.03                          3.17     1185
# 2             7.80  0.86                          3.45     1480
# 3             4.32  1.04                          2.93      735
# 4             6.75  1.05                          2.85     1450

# %%
# 7. Now set the value of the rows 3 and 4 of magnesium as NaN
wine['Magnesium'][2:4] = np.nan
wine.head()
# Out:
#    Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0     1      NaN        1.78  2.14               11.2      100.0
# 1     1      NaN        2.36  2.67               18.6      101.0
# 2     1      NaN        1.95  2.50               16.8        NaN
# 3     1    13.24        2.59  2.87               21.0        NaN
# 4     1    14.20        1.76  2.45               15.2      112.0
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# 1             5.68  1.03                          3.17     1185
# 2             7.80  0.86                          3.45     1480
# 3             4.32  1.04                          2.93      735
# 4             6.75  1.05                          2.85     1450

# %%
# 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium
wine['Alcohol'].replace(np.nan, 10, inplace= True)
wine['Magnesium'].replace(np.nan,100, inplace = True)
wine.head()
# Out:
#    Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0     1    10.00        1.78  2.14               11.2      100.0
# 1     1    10.00        2.36  2.67               18.6      101.0
# 2     1    10.00        1.95  2.50               16.8      100.0
# 3     1    13.24        2.59  2.87               21.0      100.0
# 4     1    14.20        1.76  2.45               15.2      112.0
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             4.38  1.05                          3.40     1050
# 1             5.68  1.03                          3.17     1185
# 2             7.80  0.86                          3.45     1480
# 3             4.32  1.04                          2.93      735
# 4             6.75  1.05                          2.85     1450

# %%
# 9. Count the number of missing values
wine.isnull().sum()
# Out:
# Type                            0
# Alcohol                         0
# Malic acid                      0
# Ash                             0
# Alcalinity of ash               0
# Magnesium                       0
# Total phenols                   0
# Flavanoids                      0
# Nonflavanoid phenols            0
# Proanthocyanins                 0
# Color intensity                 0
# Hue                             0
# OD280/OD315 of diluted wines    0
# Proline                         0
# dtype: int64

# %%
# 10. Create an array of 10 random numbers up until 10
import random
res =[]
for i in range(10):
    res.append(random.randint(0,10))
res
# Out:
# [8, 3, 7, 7, 0, 4, 3, 6, 5, 5]

# %%
# 11.Use random numbers you generated as an index and assign NaN value to each of cell.
wine.loc[res]=np.nan
wine.head(10)
# Out:
#    Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0   NaN      NaN         NaN   NaN                NaN        NaN
# 1   1.0     10.0        2.36  2.67               18.6      101.0
# 2   1.0     10.0        1.95  2.50               16.8      100.0
# 3   NaN      NaN         NaN   NaN                NaN        NaN
# 4   NaN      NaN         NaN   NaN                NaN        NaN
# 5   NaN      NaN         NaN   NaN                NaN        NaN
# 6   NaN      NaN         NaN   NaN                NaN        NaN
# 7   NaN      NaN         NaN   NaN                NaN        NaN
# 8   NaN      NaN         NaN   NaN                NaN        NaN
# 9   1.0     14.1        2.16  2.30               18.0      105.0
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0            NaN         NaN                   NaN              NaN
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3            NaN         NaN                   NaN              NaN
# 4            NaN         NaN                   NaN              NaN
# 5            NaN         NaN                   NaN              NaN
# 6            NaN         NaN                   NaN              NaN
# 7            NaN         NaN                   NaN              NaN
# 8            NaN         NaN                   NaN              NaN
# 9           2.95        3.32                  0.22             2.38
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0              NaN   NaN                           NaN      NaN
# 1             5.68  1.03                          3.17   1185.0
# 2             7.80  0.86                          3.45   1480.0
# 3              NaN   NaN                           NaN      NaN
# 4              NaN   NaN                           NaN      NaN
# 5              NaN   NaN                           NaN      NaN
# 6              NaN   NaN                           NaN      NaN
# 7              NaN   NaN                           NaN      NaN
# 8              NaN   NaN                           NaN      NaN
# 9             5.75  1.25                          3.17   1510.0

# %%
# 12. How many missing values do we have?
wine.isnull().sum()
# Out:
# Type                            7
# Alcohol                         7
# Malic acid                      7
# Ash                             7
# Alcalinity of ash               7
# Magnesium                       7
# Total phenols                   7
# Flavanoids                      7
# Nonflavanoid phenols            7
# Proanthocyanins                 7
# Color intensity                 7
# Hue                             7
# OD280/OD315 of diluted wines    7
# Proline                         7
# dtype: int64

# %%
# 13. Delete the rows that contain missing values
wine.dropna(inplace=True)

# %%
# 14. Print only the non-null values in alcohol
wine['Alcohol'][wine['Alcohol'] != np.nan]
# Out:
# 1      10.00
# 2      10.00
# 9      14.10
# 10     14.12
# 11     13.75
#        ...
# 172    13.71
# 173    13.40
# 174    13.27
# 175    13.17
# 176    14.13
# Name: Alcohol, Length: 170, dtype: float64

# %%
# 15. Reset the index, so it starts with 0 again
wine.reset_index()
# Out:
#      index  Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1   1.0    10.00        2.36  2.67               18.6      101.0
# 1        2   1.0    10.00        1.95  2.50               16.8      100.0
# 2        9   1.0    14.10        2.16  2.30               18.0      105.0
# 3       10   1.0    14.12        1.48  2.32               16.8       95.0
# 4       11   1.0    13.75        1.73  2.41               16.0       89.0
# ..     ...   ...      ...         ...   ...                ...        ...
# 165    172   3.0    13.71        5.65  2.45               20.5       95.0
# 166    173   3.0    13.40        3.91  2.48               23.0      102.0
# 167    174   3.0    13.27        4.28  2.26               20.0      120.0
# 168    175   3.0    13.17        2.59  2.37               20.0      120.0
# 169    176   3.0    14.13        4.10  2.74               24.5       96.0
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.24                  0.30             2.81
# 1             3.85        3.49                  0.24             2.18
# 2             2.95        3.32                  0.22             2.38
# 3             2.20        2.43                  0.26             1.57
# 4             2.60        2.76                  0.29             1.81
# ..             ...         ...                   ...              ...
# 165           1.68        0.61                  0.52             1.06
# 166           1.80        0.75                  0.43             1.41
# 167           1.59        0.69                  0.43             1.35
# 168           1.65        0.68                  0.53             1.46
# 169           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0               5.68  1.03                          3.17   1185.0
# 1               7.80  0.86                          3.45   1480.0
# 2               5.75  1.25                          3.17   1510.0
# 3               5.00  1.17                          2.82   1280.0
# 4               5.60  1.15                          2.90   1320.0
# ..               ...   ...                           ...      ...
# 165             7.70  0.64                          1.74    740.0
# 166             7.30  0.70                          1.56    750.0
# 167            10.20  0.59                          1.56    835.0
# 168             9.30  0.60                          1.62    840.0
# 169             9.20  0.61                          1.60    560.0
#
# [170 rows x 15 columns]

# %%
# Bonus: Create your own question and answer it
# Calculate the mean of Malic acid column
wine['Malic acid'].mean()
# Out:
# 2.3589411764705885
